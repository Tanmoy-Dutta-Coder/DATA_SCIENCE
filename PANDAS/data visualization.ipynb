# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
dat = {
    'month':['jan','feb','mar','april','may','june','july','aug','sep','oct','nev','dec'],
    'sales':[1201,3902,2021,5520,8900,2670,5578,3546,5847,8549,7862,4414],
    'profit':[20,30,40,45,37,65,26,14,26,44,None,55]
}
df = pd.DataFrame(dat)
# print(df)
df['sales'].sort_values()
# Out:
#     month  sales  profit
# 0     jan   1201    20.0
# 1     feb   3902    30.0
# 2     mar   2021    40.0
# 3   april   5520    45.0
# 4     may   8900    37.0
# 5    june   2670    65.0
# 6    july   5578    26.0
# 7     aug   3546    14.0
# 8     sep   5847    26.0
# 9     oct   8549    44.0
# 10    nev   7862     NaN
# 11    dec   4414    55.0

# %%
df.plot(
    x = 'sales',
    y = 'profit',
    kind = 'hexbin'
)
plt.show()

# %%
# data={
#     "Name":['ram','sam','bheem','ram','kam'],
#     "Age":[12,15,17,12,19],
#     "Gender":["male","Female","Female","male","male"],
#     "City":['Rishra','kolkata','naihati','noorpur','Diamond Hurbour'],
#     "Sub1":[85,75,96,12,45],
#     "Sub2":[75,48,92,74,88],
#     "Sub3":[45,79,98,45,85]
# }
# df=pd.DataFrame(data)
# print(df)
# Out:
#     Name  Age  Gender             City  Sub1  Sub2  Sub3
# 0    ram   12    male           Rishra    85    75    45
# 1    sam   15  Female          kolkata    75    48    79
# 2  bheem   17  Female          naihati    96    92    98
# 3    ram   12    male          noorpur    12    74    45
# 4    kam   19    male  Diamond Hurbour    45    88    85

# %%
df.plot(
    # x = 'sales',
    y = 'profit',
    kind = 'pie'
)
plt.show()

# %%
df.plot(
    x = 'sales',
    y = 'profit',
    kind = 'bar'
)
plt.show()

# %%
df.plot(
    x = 'sales',
    y = 'profit',
    kind = 'box'
)
plt.show()

# %%
df.plot(
    x = 'sales',
    y = 'profit',
    kind = 'hist'
)
plt.show()

# %%
df.plot(
    x = 'sales',
    y = 'profit',
    kind = 'line'
)
plt.show()

# %%
df.plot(
    x = 'sales',
    y = 'profit',
    kind = 'density'
)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
dat = {
    'month':['jan','feb','mar','april','may','june','july','aug','sep','oct','nev','dec'],
    'sales':[1201,3902,2021,5520,8900,2670,5578,3546,5847,8549,7862,4414],
    'profit':[20,30,40,45,37,65,26,14,26,44,None,55]
}
df = pd.DataFrame(dat)
# print(df)
df.sort_values('sales',inplace=True)
##df['newprofit']=df['profit'].sort_values()
##print(df)
##dat['sales']=dat['sales'].sort()

##df.sort_values('profit',inplace=True)
print(df)
df.plot(
    x = 'sales',
    y = 'profit',
    kind = 'area'
)
plt.show()
# Out:
#     month  sales  profit
# 0     jan   1201    20.0
# 2     mar   2021    40.0
# 5    june   2670    65.0
# 7     aug   3546    14.0
# 1     feb   3902    30.0
# 11    dec   4414    55.0
# 3   april   5520    45.0
# 6    july   5578    26.0
# 8     sep   5847    26.0
# 10    nev   7862     NaN
# 9     oct   8549    44.0
# 4     may   8900    37.0
